# %%
import pandas as pd
import os

path = r'C:\Users\Matheus\Downloads\EXCEL-CSV\tbl_fato_assuntos_R.csv'

df = pd.read_csv(path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[11], line 6
#       2 import os
#       4 path = r'C:\Users\Matheus\Downloads\EXCEL-CSV\tbl_fato_assuntos_R.csv'
# ----> 6 df = pd.read_parquet(path)
#       7 df.head()
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\pandas\io\parquet.py:669, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     666     use_nullable_dtypes = False
#     667 check_dtype_backend(dtype_backend)
# --> 669 return impl.read(
#     670     path,
#     671     columns=columns,
#     672     filters=filters,
#     673     storage_options=storage_options,
#     674     use_nullable_dtypes=use_nullable_dtypes,
#     675     dtype_backend=dtype_backend,
#     676     filesystem=filesystem,
#     677     **kwargs,
#     678 )
#
# ...

# %%
df_novos = df[df['Mais 15 anos'] == 'N']
df_novos.iloc[100]
# Out:
# Tribunal                                                                                TJSP
# Grau                                                                                      G1
# UF                                                                                        SP
# Municipio                                                                            CUBATAO
# Nome Orgao                                    SERVICO ANEXO DA FAZENDA DA COMARCA DE CUBATAO
# Ano                                                                                     2026
# Mes                                                                                        3
# Processo                                                           2050184-92.1990.8.26.0157
# Codigo da Ultima classe                                                                 1116
# Nome da Ultima classe                                                      EXECUÃÃO FISCAL
# ...

# %%
df['Grau'].unique()
# Out:
# array(['G1', 'G2', 'JE', 'TR'], dtype=object)

# %%
df['Poder publico'].unique()
# Out:
# array(['Poder_Publico-Polo_Ativo', None, 'Poder_Publico-Polo_Passivo'],
#       dtype=object)

# %%
df_novos['Materias'].groupby(df_novos['Materias']).count().sort_values(ascending=False).head(10)
# Out:
# Materias
# {}                                                14756704
# {seeu}                                              983558
# {familia}                                           722025
# {acao_penal}                                        433866
# {violencia_domestica, medida_protetiva_premio}      285402
# {previdenciario}                                    223372
# {saude_complementar, saude, assistencial}           135890
# {infancia_civel, infancia}                           98471
# {infancia_infracional, infancia}                     53622
# {saude_publica, saude, assistencial}                 51859
# Name: Materias, dtype: int64
