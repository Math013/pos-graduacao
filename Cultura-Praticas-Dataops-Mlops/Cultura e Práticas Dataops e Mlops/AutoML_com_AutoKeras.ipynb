# %% [markdown]
# # **AutoML com AutoKeras**
# - O Automated Machine Learning é também conhecido como AutoML;
# - Ferramentas e serviços que abstraem os detalhes e conhecimentos necessários para se realizar ML/DL;
# - Automatiza-se determinadas tarefas necessárias no desenvolvimento de algum modelo;
# - Geralmente, cobrem etapas de normalização de dados e engenharia de “features”; treinamento de modelos de diferentes tipos e com diferentes hiperparâmetros; avaliação e comparação de resultados;
# - Algumas ferramentas: H2O, AutoKeras e TPOT;
#
# - Vantagens:
#   - Necessário conhecimento superficial de ML/DL para se utilizar as ferramentas;
#   - Diminui o tempo para se ter resultados iniciais;
#   - Pode-se utilizar em diferentes tipos de dados e problemas (baseline);
#   - Algumas ferramentas possibilitam customizar modelos/layers;
# - Desvantagens:
#   - Customização que pode ser limitada ou dificultada;
#   - Pode-se não obter resultado bom o bastante para o problema, precisando da intervenção de especialistas;

# %%
# !pip install autokeras==1.0.19 -q

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (1.4.8)
# Requirement already satisfied: keras in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras-tuner) (3.14.1)
# Requirement already satisfied: packaging in c:\users\matheus\appdata\roaming\python\python313\site-packages (from keras-tuner) (24.2)
# Requirement already satisfied: requests in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras-tuner) (2.32.5)
# Requirement already satisfied: kt-legacy in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: grpcio in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras-tuner) (1.80.0)
# Requirement already satisfied: protobuf in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras-tuner) (6.33.5)
# Requirement already satisfied: typing-extensions~=4.12 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from grpcio->keras-tuner) (4.15.0)
# Requirement already satisfied: absl-py in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (2.4.0)
# Requirement already satisfied: numpy in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (2.3.3)
# Requirement already satisfied: rich in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (15.0.0)
# Requirement already satisfied: namex in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (0.19.1)
# Requirement already satisfied: ml-dtypes in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from keras->keras-tuner) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from requests->keras-tuner) (2025.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from rich->keras->keras-tuner) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\matheus\appdata\roaming\python\python313\site-packages (from rich->keras->keras-tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)

# %%
import tensorflow
from tensorflow import keras
from keras import preprocessing
from autokeras import StructuredDataClassifier

import os
import pandas as pd
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 from tensorflow import keras
#       3 from keras import preprocessing
# ----> 4 from autokeras import StructuredDataClassifier
#       6 import os
#       7 import pandas as pd
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\autokeras\__init__.py:15
#       1 # Copyright 2020 The AutoKeras Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from autokeras.auto_model import AutoModel
#      16 from autokeras.blocks import BertBlock
#      17 from autokeras.blocks import CategoricalToNumerical
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\autokeras\auto_model.py:26
#      23 from tensorflow import keras
#      24 from tensorflow import nest
# ---> 26 from autokeras import blocks
#      27 from autokeras import graph as graph_module
#      28 from autokeras import pipeline
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\autokeras\blocks\__init__.py:18
#      15 import tensorflow as tf
#      16 from tensorflow import keras
# ---> 18 from autokeras.blocks.basic import BertBlock
#      19 from autokeras.blocks.basic import ConvBlock
#      20 from autokeras.blocks.basic import DenseBlock
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\autokeras\blocks\basic.py:25
#      22 from tensorflow.keras import applications
#      23 from tensorflow.keras import layers
# ---> 25 from autokeras import keras_layers
#      26 from autokeras.blocks import reduction
#      27 from autokeras.engine import block as block_module
#
# File c:\Users\Matheus\miniconda3\envs\PUC\Lib\site-packages\autokeras\keras_layers.py:27
#      25 from tensorflow import nest
#      26 from tensorflow.keras import layers
# ---> 27 from tensorflow.keras.layers.experimental import preprocessing
#      29 from autokeras import constants
#      30 from autokeras.utils import data_utils
#
# ModuleNotFoundError: No module named 'tensorflow.keras.layers.experimental'

# %%
# %%time
# !rm -r lectures-cdas-2023
# !git clone https://github.com/renansantosmendes/lectures-cdas-2023.git
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.
# CPU times: total: 46.9 ms
# Wall time: 892 ms
# Cloning into 'lectures-cdas-2023'...

# %%
data = pd.read_csv(os.path.join('lectures-cdas-2023', 'fetal_health.csv'))

# %%
X=data.drop(["fetal_health"], axis=1)
y=data["fetal_health"]

columns_names = list(X.columns)
X_df = sklearn.preprocessing.StandardScaler().fit_transform(X)
X_df = pd.DataFrame(X_df, columns=columns_names)

X_train, X_test, y_train, y_test = train_test_split(X_df, y, test_size=0.3, random_state=42)
y_train=keras.utils.to_categorical(y_train)[:,1:]
y_test=keras.utils.to_categorical(y_test)[:,1:]

# %%
# %%time
clf = StructuredDataClassifier(overwrite=True, max_trials=15)
clf.fit(x=X_train, y=y_train, epochs=10)

# %%
model = clf.export_model()

# %%
model.summary()

# %%
model.evaluate(X_test, y_test)
