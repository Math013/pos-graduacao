# %% [markdown]
# # **FRAMEWORKS DE DEEPLEARNING**
# # **Prática - PyTorch**
# **Autor**: Renan Santos Mendes
#
# **Email**: renansantosmendes@gmail.com
#
# **Descrição**: Este notebook apresenta uma introdução ao framework PyTorch.

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Collecting torch
#   Downloading https://download-r2.pytorch.org/whl/cu126/torch-2.12.0%2Bcu126-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting torchvision
#   Downloading https://download-r2.pytorch.org/whl/cu126/torchvision-0.27.0%2Bcu126-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from torch) (72.1.0)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from torchvision) (2.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from torchvision) (11.1.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matheus\miniconda3\envs\puc\lib\site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download-r2.pytorch.org/whl/cu126/torch-2.12.0%2Bcu126-cp313-cp313-win_amd64.whl (2620.8 MB)
#    ---------------------------------------- 0.0/2.6 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.6 GB 57.3 MB/s eta 0:00:46
#    ---------------------------------------- 0.0/2.6 GB 60.2 MB/s eta 0:00:44
#     --------------------------------------- 0.0/2.6 GB 59.1 MB/s eta 0:00:44
#     --------------------------------------- 0.0/2.6 GB 58.1 MB/s eta 0:00:45
#     --------------------------------------- 0.1/2.6 GB 61.0 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 60.7 MB/s eta 0:00:42
#    - -------------------------------------- 0.1/2.6 GB 62.1 MB/s eta 0:00:41
#    - -------------------------------------- 0.1/2.6 GB 66.2 MB/s eta 0:00:38
#    -- ------------------------------------- 0.1/2.6 GB 72.1 MB/s eta 0:00:35
#    -- ------------------------------------- 0.2/2.6 GB 76.8 MB/s eta 0:00:33
#    -- ------------------------------------- 0.2/2.6 GB 80.6 MB/s eta 0:00:31
#    --- ------------------------------------ 0.2/2.6 GB 83.7 MB/s eta 0:00:29
#    --- ------------------------------------ 0.2/2.6 GB 86.4 MB/s eta 0:00:28
#    ---- ----------------------------------- 0.3/2.6 GB 88.8 MB/s eta 0:00:27
#    ---- ----------------------------------- 0.3/2.6 GB 95.4 MB/s eta 0:00:25
#    ---- ----------------------------------- 0.3/2.6 GB 105.0 MB/s eta 0:00:22
#    ----- ---------------------------------- 0.3/2.6 GB 112.0 MB/s eta 0:00:21
#    ----- ---------------------------------- 0.4/2.6 GB 118.3 MB/s eta 0:00:20
#    ----- ---------------------------------- 0.4/2.6 GB 118.3 MB/s eta 0:00:19
#    ------ --------------------------------- 0.4/2.6 GB 118.4 MB/s eta 0:00:19
#    ------ --------------------------------- 0.4/2.6 GB 117.2 MB/s eta 0:00:19
#    ------ --------------------------------- 0.5/2.6 GB 112.9 MB/s eta 0:00:20
#    ------- -------------------------------- 0.5/2.6 GB 109.3 MB/s eta 0:00:20
#    ------- -------------------------------- 0.5/2.6 GB 106.5 MB/s eta 0:00:21
#    ------- -------------------------------- 0.5/2.6 GB 102.8 MB/s eta 0:00:21
#    ------- -------------------------------- 0.5/2.6 GB 100.6 MB/s eta 0:00:21
#    -------- ------------------------------- 0.5/2.6 GB 97.2 MB/s eta 0:00:22
#    -------- ------------------------------- 0.5/2.6 GB 94.5 MB/s eta 0:00:22
#    -------- ------------------------------- 0.6/2.6 GB 91.9 MB/s eta 0:00:23
#    -------- ------------------------------- 0.6/2.6 GB 89.5 MB/s eta 0:00:23
#    --------- ------------------------------ 0.6/2.6 GB 87.2 MB/s eta 0:00:24
#    --------- ------------------------------ 0.6/2.6 GB 85.1 MB/s eta 0:00:24
#    --------- ------------------------------ 0.6/2.6 GB 83.0 MB/s eta 0:00:24
#    --------- ------------------------------ 0.6/2.6 GB 81.7 MB/s eta 0:00:25
#    ---------- ----------------------------- 0.7/2.6 GB 79.1 MB/s eta 0:00:25
#    ---------- ----------------------------- 0.7/2.6 GB 77.5 MB/s eta 0:00:26
#    ---------- ----------------------------- 0.7/2.6 GB 75.6 MB/s eta 0:00:26
#    ---------- ----------------------------- 0.7/2.6 GB 76.1 MB/s eta 0:00:26
#    ----------- ---------------------------- 0.7/2.6 GB 76.1 MB/s eta 0:00:25
#    ----------- ---------------------------- 0.7/2.6 GB 76.1 MB/s eta 0:00:25
#    ----------- ---------------------------- 0.8/2.6 GB 76.0 MB/s eta 0:00:25
#    ----------- ---------------------------- 0.8/2.6 GB 76.1 MB/s eta 0:00:25
#    ------------ --------------------------- 0.8/2.6 GB 76.1 MB/s eta 0:00:25
#    ------------ --------------------------- 0.8/2.6 GB 76.1 MB/s eta 0:00:24
#    ------------ --------------------------- 0.8/2.6 GB 76.2 MB/s eta 0:00:24
#    ------------ --------------------------- 0.8/2.6 GB 76.2 MB/s eta 0:00:24
#    ------------- -------------------------- 0.9/2.6 GB 76.2 MB/s eta 0:00:24
#    ------------- -------------------------- 0.9/2.6 GB 76.1 MB/s eta 0:00:23
#    ------------- -------------------------- 0.9/2.6 GB 76.1 MB/s eta 0:00:23
#    ------------- -------------------------- 0.9/2.6 GB 76.3 MB/s eta 0:00:23
#    -------------- ------------------------- 0.9/2.6 GB 76.3 MB/s eta 0:00:23
#    -------------- ------------------------- 0.9/2.6 GB 76.3 MB/s eta 0:00:23
#    -------------- ------------------------- 1.0/2.6 GB 76.4 MB/s eta 0:00:22
#    -------------- ------------------------- 1.0/2.6 GB 76.3 MB/s eta 0:00:22
#    --------------- ------------------------ 1.0/2.6 GB 76.3 MB/s eta 0:00:22
#    --------------- ------------------------ 1.0/2.6 GB 76.3 MB/s eta 0:00:22
#    --------------- ------------------------ 1.0/2.6 GB 76.3 MB/s eta 0:00:21
#    --------------- ------------------------ 1.0/2.6 GB 76.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 1.1/2.6 GB 76.2 MB/s eta 0:00:21
#    ---------------- ----------------------- 1.1/2.6 GB 76.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 1.1/2.6 GB 76.3 MB/s eta 0:00:21
#    ---------------- ----------------------- 1.1/2.6 GB 76.3 MB/s eta 0:00:20
#    ----------------- ---------------------- 1.1/2.6 GB 76.3 MB/s eta 0:00:20
#    ----------------- ---------------------- 1.1/2.6 GB 76.2 MB/s eta 0:00:20
#    ----------------- ---------------------- 1.1/2.6 GB 76.2 MB/s eta 0:00:20
#    ----------------- ---------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:20
#    ------------------ --------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:19
#    ------------------ --------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:19
#    ------------------ --------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:19
#    ------------------ --------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:19
#    ------------------- -------------------- 1.2/2.6 GB 76.2 MB/s eta 0:00:19
#    ------------------- -------------------- 1.3/2.6 GB 76.2 MB/s eta 0:00:18
#    ------------------- -------------------- 1.3/2.6 GB 76.4 MB/s eta 0:00:18
#    ------------------- -------------------- 1.3/2.6 GB 76.3 MB/s eta 0:00:18
#    -------------------- ------------------- 1.3/2.6 GB 76.4 MB/s eta 0:00:18
#    -------------------- ------------------- 1.3/2.6 GB 76.5 MB/s eta 0:00:17
#    -------------------- ------------------- 1.3/2.6 GB 76.4 MB/s eta 0:00:17
#    -------------------- ------------------- 1.4/2.6 GB 76.3 MB/s eta 0:00:17
#    --------------------- ------------------ 1.4/2.6 GB 76.3 MB/s eta 0:00:17
#    --------------------- ------------------ 1.4/2.6 GB 76.3 MB/s eta 0:00:17
#    --------------------- ------------------ 1.4/2.6 GB 76.3 MB/s eta 0:00:16
#    --------------------- ------------------ 1.4/2.6 GB 76.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 1.4/2.6 GB 76.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 1.5/2.6 GB 76.3 MB/s eta 0:00:16
#    ---------------------- ----------------- 1.5/2.6 GB 76.1 MB/s eta 0:00:16
#    ---------------------- ----------------- 1.5/2.6 GB 76.2 MB/s eta 0:00:15
#    ---------------------- ----------------- 1.5/2.6 GB 75.6 MB/s eta 0:00:15
#    ----------------------- ---------------- 1.5/2.6 GB 74.1 MB/s eta 0:00:15
#    ----------------------- ---------------- 1.5/2.6 GB 75.8 MB/s eta 0:00:15
#    ----------------------- ---------------- 1.6/2.6 GB 75.5 MB/s eta 0:00:15
#    ----------------------- ---------------- 1.6/2.6 GB 74.9 MB/s eta 0:00:15
#    ------------------------ --------------- 1.6/2.6 GB 74.3 MB/s eta 0:00:14
#    ------------------------ --------------- 1.6/2.6 GB 75.5 MB/s eta 0:00:14
#    ------------------------ --------------- 1.6/2.6 GB 75.7 MB/s eta 0:00:14
#    ------------------------ --------------- 1.6/2.6 GB 75.6 MB/s eta 0:00:14
#    ------------------------- -------------- 1.7/2.6 GB 75.6 MB/s eta 0:00:13
#    ------------------------- -------------- 1.7/2.6 GB 75.4 MB/s eta 0:00:13
#    ------------------------- -------------- 1.7/2.6 GB 75.3 MB/s eta 0:00:13
#    ------------------------- -------------- 1.7/2.6 GB 75.5 MB/s eta 0:00:13
#    -------------------------- ------------- 1.7/2.6 GB 75.3 MB/s eta 0:00:13
#    -------------------------- ------------- 1.7/2.6 GB 75.4 MB/s eta 0:00:12
#    -------------------------- ------------- 1.7/2.6 GB 75.6 MB/s eta 0:00:12
#    -------------------------- ------------- 1.8/2.6 GB 75.7 MB/s eta 0:00:12
#    --------------------------- ------------ 1.8/2.6 GB 77.6 MB/s eta 0:00:11
#    --------------------------- ------------ 1.8/2.6 GB 75.8 MB/s eta 0:00:11
#    --------------------------- ------------ 1.8/2.6 GB 76.1 MB/s eta 0:00:11
#    --------------------------- ------------ 1.8/2.6 GB 76.9 MB/s eta 0:00:11
#    ---------------------------- ----------- 1.8/2.6 GB 77.3 MB/s eta 0:00:11
#    ---------------------------- ----------- 1.9/2.6 GB 76.3 MB/s eta 0:00:10
#    ---------------------------- ----------- 1.9/2.6 GB 76.1 MB/s eta 0:00:10
#    ---------------------------- ----------- 1.9/2.6 GB 76.2 MB/s eta 0:00:10
#    ----------------------------- ---------- 1.9/2.6 GB 76.3 MB/s eta 0:00:10
#    ----------------------------- ---------- 1.9/2.6 GB 76.4 MB/s eta 0:00:10
#    ----------------------------- ---------- 1.9/2.6 GB 76.7 MB/s eta 0:00:09
#    ----------------------------- ---------- 2.0/2.6 GB 76.6 MB/s eta 0:00:09
#    ------------------------------ --------- 2.0/2.6 GB 76.6 MB/s eta 0:00:09
#    ------------------------------ --------- 2.0/2.6 GB 76.8 MB/s eta 0:00:09
#    ------------------------------ --------- 2.0/2.6 GB 76.6 MB/s eta 0:00:08
#    ------------------------------ --------- 2.0/2.6 GB 76.6 MB/s eta 0:00:08
#    ------------------------------- -------- 2.0/2.6 GB 76.4 MB/s eta 0:00:08
#    ------------------------------- -------- 2.1/2.6 GB 76.6 MB/s eta 0:00:08
#    ------------------------------- -------- 2.1/2.6 GB 76.7 MB/s eta 0:00:08
#    ------------------------------- -------- 2.1/2.6 GB 76.8 MB/s eta 0:00:07
#    -------------------------------- ------- 2.1/2.6 GB 76.8 MB/s eta 0:00:07
#    -------------------------------- ------- 2.1/2.6 GB 76.4 MB/s eta 0:00:07
#    -------------------------------- ------- 2.1/2.6 GB 76.6 MB/s eta 0:00:07
#    -------------------------------- ------- 2.2/2.6 GB 76.2 MB/s eta 0:00:07
#    --------------------------------- ------ 2.2/2.6 GB 76.5 MB/s eta 0:00:06
#    --------------------------------- ------ 2.2/2.6 GB 76.1 MB/s eta 0:00:06
#    --------------------------------- ------ 2.2/2.6 GB 76.4 MB/s eta 0:00:06
#    --------------------------------- ------ 2.2/2.6 GB 76.5 MB/s eta 0:00:06
#    ---------------------------------- ----- 2.2/2.6 GB 76.3 MB/s eta 0:00:06
#    ---------------------------------- ----- 2.3/2.6 GB 76.6 MB/s eta 0:00:05
#    ---------------------------------- ----- 2.3/2.6 GB 76.6 MB/s eta 0:00:05
#    ---------------------------------- ----- 2.3/2.6 GB 75.4 MB/s eta 0:00:05
#    ---------------------------------- ----- 2.3/2.6 GB 73.4 MB/s eta 0:00:05
#    ----------------------------------- ---- 2.3/2.6 GB 75.7 MB/s eta 0:00:05
#    ----------------------------------- ---- 2.3/2.6 GB 76.1 MB/s eta 0:00:04
#    ----------------------------------- ---- 2.3/2.6 GB 76.0 MB/s eta 0:00:04
#    ------------------------------------ --- 2.4/2.6 GB 75.9 MB/s eta 0:00:04
#    ------------------------------------ --- 2.4/2.6 GB 76.1 MB/s eta 0:00:04
#    ------------------------------------ --- 2.4/2.6 GB 76.2 MB/s eta 0:00:03
#    ------------------------------------ --- 2.4/2.6 GB 76.7 MB/s eta 0:00:03
#    ------------------------------------- -- 2.4/2.6 GB 76.1 MB/s eta 0:00:03
#    ------------------------------------- -- 2.4/2.6 GB 76.8 MB/s eta 0:00:03
#    ------------------------------------- -- 2.5/2.6 GB 76.4 MB/s eta 0:00:03
#    ------------------------------------- -- 2.5/2.6 GB 76.2 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 76.4 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 76.2 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 76.3 MB/s eta 0:00:02
#    -------------------------------------- - 2.5/2.6 GB 79.9 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 78.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.9 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.7 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------  2.6/2.6 GB 76.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 GB 42.7 MB/s  0:00:35
# Downloading https://download-r2.pytorch.org/whl/cu126/torchvision-0.27.0%2Bcu126-cp313-cp313-win_amd64.whl (8.8 MB)
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    ---------------------------------------- 8.8/8.8 MB 69.5 MB/s  0:00:00
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 26.3 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.3 MB 29.6 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 27.9 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 16.0 MB/s  0:00:00
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ---------------------------------------- 0/7 [mpmath]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----- ---------------------------------- 1/7 [sympy]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------- ---------------------------- 2/7 [networkx]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ----------------- ---------------------- 3/7 [fsspec]
#    ---------------------- ----------------- 4/7 [filelock]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------- ----------- 5/7 [torch]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------- ----- 6/7 [torchvision]
#    ---------------------------------------- 7/7 [torchvision]
#
# Successfully installed filelock-3.29.0 fsspec-2026.4.0 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0 torch-2.12.0+cu126 torchvision-0.27.0+cu126

# %%
import torch

# %%
torch.__version__
# Out:
# '2.12.0+cu126'

# %%
tensor_1 = torch.Tensor([1, 2, 3])

# %%
tensor_1
# Out:
# tensor([1., 2., 3.])

# %%
tensor_1.nelement()
# Out:
# 3

# %% [markdown]
#  ## **Tipos de Tensores**

# %%
torch.IntTensor([1, 2, 3])
# Out:
# tensor([1, 2, 3], dtype=torch.int32)

# %%
torch.FloatTensor([1, 2, 3])
# Out:
# tensor([1., 2., 3.])

# %%
torch.BoolTensor([1, 2, 3])
# Out:
# tensor([True, True, True])

# %%
complex_tensor = torch.randn(1,2)

# %%
complex_tensor
# Out:
# tensor([[1.7331, 1.1063]])

# %%
complex_tensor[0][0]
# Out:
# tensor(1.7331)

# %%
complex_tensor.squeeze().shape
# Out:
# torch.Size([2])

# %%
complex(1,2)
# Out:
# (1+2j)

# %%
torch.view_as_complex(complex_tensor)
# Out:
# tensor([1.7331+1.1063j])

# %% [markdown]
#  ## **Conversão entre tipos de tensores**

# %%
tensor_1.bool()
# Out:
# tensor([True, True, True])

# %%
tensor_1.half()
# Out:
# tensor([1., 2., 3.], dtype=torch.float16)

# %%
tensor_1.bfloat16()
# Out:
# tensor([1., 2., 3.], dtype=torch.bfloat16)

# %% [markdown]
#  ## **Operações**

# %%
tensor_a = torch.Tensor([1, 2, 3])
tensor_b = torch.Tensor([4, 5, 6])

# %% [markdown]
# ####**Adição**

# %% [markdown]
# ####**Subtração**

# %% [markdown]
# ####**Multiplicação**

# %% [markdown]
# ####**Divisão**

# %% [markdown]
# ##**Operações Matriciais**

# %%
tensor_1 = torch.Tensor([[1, 4]])

tensor_2 = torch.Tensor([[1, -2], [3, 2]])

# %%
...

# %% [markdown]
# ## **Operações Tensoriais**

# %% [markdown]
# ####**Divisão**

# %% [markdown]
# ## **Gradientes e Autograd**

# %%
x =

# %% [markdown]
# $f(x) = x^3$

# %% [markdown]
# $\frac{d f(x)}{dx} = 3x^2 = 3(2)^2 = 12$

# %%
...

# %% [markdown]
# ####**Grafo do Tensor**

# %%
# %%capture
# !pip install torchviz
# !apt-get install graphviz -qq

# %%
import torch
from torchviz import make_dot
from IPython.display import display

# %%
x = torch.randn(2, 3, requires_grad=True)
y = torch.randn(3, 4, requires_grad=True)
z = x @ y
loss = z.sum()

dot = make_dot(loss, params={'x': x, 'y': y})
display(dot)
